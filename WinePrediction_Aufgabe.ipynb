# %% [markdown]
# Importing the Dependencies

# %% [markdown]
# Laut Herr Resanovic:
#
# - 3 Modelle

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ## Problem Statement
# The wine company wants to create new wine brand. The company wants to be able to infer the quality of the wine based on the several chemical components in wine. Therefore you should build the ML model which is capable to recongnise the quality of the wine based on the chemical properties. See wine data.

# %% [markdown]
# ## Data Import
# Import the winedate.csv

# %%
df = pd.read_csv("winedata.csv")
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %% [markdown]
# ## Data Analysis
# Initial decision which Models/Algorithms are going to be used as potential candidates for the final model. Elaborate why these models

# %% [markdown]
# Als erstes Modell um sich zu orientieren verwenden wir die lineare Regression da sie einen simplen Einstiegspunkt gibt und gut interpretierbar ist.
#
# Initial da wir die Weine anhand ihrer Qualität auf einer Skala 1-10 Einordnen wollen war unser erster Gedanke dass wir einen Regressions Algorithmus verwenden wollen.
#
# Als mögliche Modelle haben wir uns für: RandomForestRegressor, XGBRegressor und Support Vector Regressor entschieden.
#
# Der RandomForestRegressor ist robust und nichtlinear. Ausreißer egal, Rauschen egal, Overfitting egal. Nichtlinear super weil daten nicht linear
#
# XGB erkennt nichtlineare Muster und man kann viel tunen, Tabellarische Daten sehr gut, ungleich verteilte Daten sehr gut, auch robust, auch ohne viel tuning gute performance,
#
# Lasso
#
# SVR

# %% [markdown]
# ## Data Preprocessing
# Here you should prepare data accordingly

# %%
#auf Nullwerte prüfen
print(df.isnull().sum())
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
#auf Duplikate prüfen
df.duplicated().sum()
# Out:
# np.int64(240)

# %%
#initial 240 Duplikate gefunden, diese gelöscht
df.drop_duplicates()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 5               7.4             0.660         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 1593            6.8             0.620         0.08             1.9      0.068
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
#Zielwert vom Features trennen damit Zielwert nicht verfälscht wird da das Modell den Zielwert basierend auf den Features lernen soll
X = df.drop("quality", axis=1)
y = df["quality"]

X.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol
# 0      9.4
# 1      9.8
# 2      9.8
# 3      9.8
# 4      9.4

# %%
#skalieren damit alle Werte auf der gleichen Skala sind und Ausreißer nicht so stark ins Gewicht fallen

#hätten die Trainings/Testsplits skalieren sollen nicht den ganten DataFrame :(

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

df_scaled = pd.DataFrame(X_scaled, columns=df.drop("quality", axis=1).columns)

df_scaled.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0      -0.528360          0.961877    -1.391472       -0.453218  -0.243707
# 1      -0.298547          1.967442    -1.391472        0.043416   0.223875
# 2      -0.298547          1.297065    -1.186070       -0.169427   0.096353
# 3       1.654856         -1.384443     1.484154       -0.453218  -0.264960
# 4      -0.528360          0.961877    -1.391472       -0.453218  -0.243707
# 5      -0.528360          0.738418    -1.391472       -0.524166  -0.264960
# 6      -0.241094          0.403229    -1.083370       -0.666062  -0.392483
# 7      -0.585813          0.682553    -1.391472       -0.949853  -0.477498
# 8      -0.298547          0.291499    -1.288771       -0.382271  -0.307468
# 9      -0.470907         -0.155419     0.457144        2.526589  -0.349975
#
#    free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# ...

# %% [markdown]
# ## Training and build Models
# These models will be used for the evaluation

# %%
# Splitten der Daten in Test und Train Split, Aufteilung hier 75% Training und 25% Testing. RandomState = 1
# Skalieren für Tree Based Models zwar nicht notwendig da sie robust sind, jedoch schadet es auch nicht und für Lineare Regression oder 
# Lasso wichtig da hier ein großer numerischer Ausreißer höher gewichtet wird, nicht weil er besonders Relevant ist sondern weil es einfach eine
# große Zahl ist
X_train0, X_test0, y_train0, y_test0 = train_test_split(X, y, test_size=0.25, random_state=1)

X_train0 = scaler.fit_transform(X_train0)
X_test0 = scaler.transform(X_test0)

# %%
#Modell initialisieren
linear_regression = LinearRegression()

#Modell trainieren
linear_regression.fit(X_train0, y_train0)

#Vorhersagen treffen
y_prediction = linear_regression.predict(X_test0)

#Bewertung
mse = mean_squared_error(y_test0, y_prediction)

print("MSE Lineare Regression:", mse)
# Out:
# MSE Lineare Regression: 0.3865813862375548

# %% [markdown]
# ## Evaluation and selection of the model
# Here multiple models should be evaluated and finaly selected.
#
# ### Accuracy score
#
# ### Precision
#
# ### Recall
#
# ### F1 Score

# %% [markdown]
# ## Conclusion and reflection
# Please reflect on the project and provide the conclusion

# %% [markdown]
# ## Test the model with some data
# Create your own new data representing wine and test the model
